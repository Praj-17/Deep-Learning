# %%
##Data augmentation using python and keras
from keras_preprocessing.image import ImageDataGenerator, img_to_array, load_img
import os

datagen = ImageDataGenerator(
    rotation_range=0,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode= 'nearest'
)
def Augmentation(directory, save_to, save_as,n_augments):
   for imgname in os.listdir(directory):
        img_path  = str(f"{directory}\\{imgname}")
        print(img_path)
        img = load_img(img_path)
        x = img_to_array(img)  # this is a Numpy array with shape (3, 150, 150)
        x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)

        # the .flow() command below generates batches of randomly transformed images
        # and saves the results to the `preview/` directory
        i = 0
        print("Augmenting....it may take around 2 to 3 minutes")
        for batch in datagen.flow(x, batch_size=1,
                                save_to_dir=save_to, save_prefix=f"{imgname}_{save_as}", save_format='jpeg'):
            i += 1
            if i > n_augments:
                # print(f"Augmentation Complete! Check your {save_to} directory")
                break  # otherwise the generator would loop indefinitely
   print("Augmentation done for all images!!!!!!!!!!!!!!!!!!!!!!!!!!!1")

Augmentation('p', 'p', 'augmented', 5)
# Out:
# p\elephantsinjungle10.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle11.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle13.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle14.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle15.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle16.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle19.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle20.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle21.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle23.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle24.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle26.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle27.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle28.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle29.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle3.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle30.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle31.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle32.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle34.jpeg_augmented_0_8248.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle37.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle38.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle4.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle40.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle41.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle42.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle43.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle45.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle46.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle48.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle5.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle6.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle7.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle8.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\elephantsinjungle9.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad0.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad1.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad11.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad12.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad13.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad16.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad2.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad21.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad23.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad24.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad25.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad26.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad27.jpeg_augmented_0_8927.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad29.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad3.jpeg_augmented_0_7170.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad30.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad31.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad32.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad33.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad34.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad35.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad38.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad39.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad4.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad40.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad41.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad42.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad44.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad48.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad49.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad5.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad6.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad7.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad9.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad9.jpeg_augmented_0_3945.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad9.jpeg_augmented_0_8960.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad9.jpeg_augmented_0_9181.jpeg
# Augmenting....it may take around 2 to 3 minutes
# p\Elephantsonroad9.jpeg_augmented_0_9827.jpeg
# Augmenting....it may take around 2 to 3 minutes
# Augmentation done for all images!!!!!!!!!!!!!!!!!!!!!!!!!!!1

# %%
# %pip install aspose
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pwayk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-image (c:\users\pwayk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pwayk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-image (c:\users\pwayk\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement aspose (from versions: none)
# ERROR: No matching distribution found for aspose
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pwayk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-image (c:\users\pwayk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pwayk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-image (c:\users\pwayk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\pwayk\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-image (c:\users\pwayk\anaconda3\lib\site-packages)

# %%
import aspose.words as aw
import os
doc = aw.Document()
builder = aw.DocumentBuilder(doc)

for i in os.listdir('p'):
    name = i.split('.')[0]
    shape = builder.insert_image(f'p/{name}')
    shape.image_data.save(f"P/{name}.bmp")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24568/2439320627.py in <module>
# ----> 1 import aspose.words as aw
#       2 import os
#       3 doc = aw.Document()
#       4 builder = aw.DocumentBuilder(doc)
#       5
#
# ModuleNotFoundError: No module named 'aspose'

# %%
from PIL import Image
import numpy as np
import os

for i in os.listdir('p'):
    name = i.split('.')[0]
    img = Image.open(f'p/{i}')
    ary = np.array(img)

    # Split the three channels
    r,g,b = np.split(ary,3,axis=2)
    r=r.reshape(-1)
    g=r.reshape(-1)
    b=r.reshape(-1)

    # Standard RGB to grayscale 
    bitmap = list(map(lambda x: 0.299*x[0]+0.587*x[1]+0.114*x[2], 
    zip(r,g,b)))
    bitmap = np.array(bitmap).reshape([ary.shape[0], ary.shape[1]])
    bitmap = np.dot((bitmap > 128).astype(float),255)
    im = Image.fromarray(bitmap.astype(np.uint8))
    im.save(f'Positives/{name}.bmp')
